# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/harsnyi/Documents/NYC-Crash-Analysis/data/Motor_Vehicle_Collisions_-_Crashes_20241020.csv")
# Out:
# /var/folders/tw/j102_3791q18mc8161tjddq00000gn/T/ipykernel_25839/372255331.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/harsnyi/Documents/NYC-Crash-Analysis/data/Motor_Vehicle_Collisions_-_Crashes_20241020.csv")

# %%
df_sampled = df.sample(100)

# %%
df_sampled
# Out:
#          CRASH DATE CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 452898   03/31/2019      14:15        NaN      NaN        NaN        NaN
# 1831808  12/20/2012      19:00   BROOKLYN    11228  40.611405 -74.009512
# 438919   05/01/2019      11:45     QUEENS  11372.0  40.749280 -73.888840
# 483724   02/16/2019      16:30        NaN      NaN        NaN        NaN
# 878916   05/29/2017      19:00        NaN      NaN        NaN        NaN
# ...             ...        ...        ...      ...        ...        ...
# 1336802  05/15/2015      17:50     QUEENS  11691.0  40.599502 -73.754068
# 359641   09/01/2019      13:40     QUEENS  11429.0  40.715015 -73.741646
# 946999   01/29/2017       4:40        NaN      NaN  40.712410 -73.834680
# 1858918  10/20/2012       9:00     QUEENS    11362  40.767865 -73.738175
# 1590587  02/24/2014       9:35  MANHATTAN    10032  40.830892 -73.941367
#
#                           LOCATION                    ON STREET NAME  \
# ...

# %%
df_sampled.to_csv("/Users/harsnyi/Documents/NYC-Crash-Analysis/data/NYC_motor_vehicle_collisions_sampled.csv")
