# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes_20241020.csv")
# Out:
# /var/folders/tw/j102_3791q18mc8161tjddq00000gn/T/ipykernel_53122/1688408283.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("Motor_Vehicle_Collisions_-_Crashes_20241020.csv")

# %%
df["CRASH DATE"] = pd.to_datetime(df["CRASH DATE"], format='%m/%d/%Y')

# %%
df["CRASH TIME"] = pd.to_datetime(df["CRASH TIME"], format='%H:%M')

# %%
df["HOUR"] = df["CRASH TIME"].dt.hour
df["MINUTE"] = df["CRASH TIME"].dt.minute

# %%
df['YEAR'] = df['CRASH DATE'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127517 entries, 0 to 2127516
# Data columns (total 32 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     datetime64[ns]
#  1   CRASH TIME                     datetime64[ns]
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
df.head(20)
# Out:
#    CRASH DATE          CRASH TIME    BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  2021-09-11 1900-01-01 02:39:00        NaN      NaN        NaN        NaN
# 1  2022-03-26 1900-01-01 11:45:00        NaN      NaN        NaN        NaN
# 2  2022-06-29 1900-01-01 06:55:00        NaN      NaN        NaN        NaN
# 3  2021-09-11 1900-01-01 09:35:00   BROOKLYN  11208.0  40.667202 -73.866500
# 4  2021-12-14 1900-01-01 08:13:00   BROOKLYN  11233.0  40.683304 -73.917274
# 5  2021-04-14 1900-01-01 12:47:00        NaN      NaN        NaN        NaN
# 6  2021-12-14 1900-01-01 17:05:00        NaN      NaN  40.709183 -73.956825
# 7  2021-12-14 1900-01-01 08:17:00      BRONX  10475.0  40.868160 -73.831480
# 8  2021-12-14 1900-01-01 21:10:00   BROOKLYN  11207.0  40.671720 -73.897100
# 9  2021-12-14 1900-01-01 14:58:00  MANHATTAN  10017.0  40.751440 -73.973970
# 10 2021-12-13 1900-01-01 00:34:00        NaN      NaN  40.701275 -73.888870
# ...

# %%
df["CONTRIBUTING FACTOR VEHICLE 2"].unique()
# Out:
# array(['Unspecified', nan, 'Other Vehicular',
#        'Driver Inattention/Distraction', 'Traffic Control Disregarded',
#        'Passing or Lane Usage Improper', 'Reaction to Uninvolved Vehicle',
#        'Following Too Closely', 'Unsafe Speed',
#        'Aggressive Driving/Road Rage', 'Turning Improperly',
#        'Failure to Yield Right-of-Way', 'Driver Inexperience',
#        'View Obstructed/Limited', 'Oversized Vehicle',
#        'Passing Too Closely', 'Unsafe Lane Changing', 'Pavement Slippery',
#        'Pedestrian/Bicyclist/Other Pedestrian Error/Confusion',
#        'Fell Asleep', 'Backing Unsafely', 'Obstruction/Debris',
#        'Alcohol Involvement', 'Outside Car Distraction',
#        'Passenger Distraction', 'Glare', 'Vehicle Vandalism',
#        'Traffic Control Device Improper/Non-Working', 'Tinted Windows',
#        'Tow Hitch Defective', 'Brakes Defective', 'Steering Failure',
#        'Pavement Defective', 'Failure to Keep Right',
# ...

# %%
unique_vehicles = df["VEHICLE TYPE CODE 1"].unique()

# %%
unique_vehicles
# Out:
# array(['Sedan', nan, 'Dump', ..., 'FREIGHT', 'VOLVO', 'Cmix'],
#       dtype=object)

# %%
df_borough = df[df["BOROUGH"].notnull()]

# %%
df_borough
# Out:
#         CRASH DATE          CRASH TIME    BOROUGH ZIP CODE   LATITUDE  \
# 3       2021-09-11 1900-01-01 09:35:00   BROOKLYN  11208.0  40.667202
# 4       2021-12-14 1900-01-01 08:13:00   BROOKLYN  11233.0  40.683304
# 7       2021-12-14 1900-01-01 08:17:00      BRONX  10475.0  40.868160
# 8       2021-12-14 1900-01-01 21:10:00   BROOKLYN  11207.0  40.671720
# 9       2021-12-14 1900-01-01 14:58:00  MANHATTAN  10017.0  40.751440
# ...            ...                 ...        ...      ...        ...
# 2127474 2024-07-19 1900-01-01 18:00:00   BROOKLYN  11207.0  40.675735
# 2127491 2024-07-07 1900-01-01 14:12:00      BRONX  10468.0  40.861084
# 2127501 2024-07-21 1900-01-01 18:05:00   BROOKLYN  11224.0  40.572968
# 2127502 2024-05-12 1900-01-01 10:34:00     QUEENS  11413.0  40.684760
# 2127513 2024-08-06 1900-01-01 12:00:00     QUEENS  11001.0        NaN
#
#          LONGITUDE                 LOCATION   ON STREET NAME  \
# 3       -73.866500    (40.667202, -73.8665)              NaN
# ...

# %%
df_borough["LATITUDE"].isnull().sum()
# Out:
# np.int64(37313)

# %%
df_borough["LONGITUDE"].isnull().sum()
# Out:
# np.int64(37313)

# %%
df.to_csv("/Users/harsnyi/Documents/NYC-Crash-Analysis/data/records.csv", index=False)

# %%
cols = [{"name": col, "id": col} for col in df.columns]

# %%
cols
# Out:
# [{'name': 'CRASH DATE', 'id': 'CRASH DATE'},
#  {'name': 'CRASH TIME', 'id': 'CRASH TIME'},
#  {'name': 'BOROUGH', 'id': 'BOROUGH'},
#  {'name': 'ZIP CODE', 'id': 'ZIP CODE'},
#  {'name': 'LATITUDE', 'id': 'LATITUDE'},
#  {'name': 'LONGITUDE', 'id': 'LONGITUDE'},
#  {'name': 'LOCATION', 'id': 'LOCATION'},
#  {'name': 'ON STREET NAME', 'id': 'ON STREET NAME'},
#  {'name': 'CROSS STREET NAME', 'id': 'CROSS STREET NAME'},
#  {'name': 'OFF STREET NAME', 'id': 'OFF STREET NAME'},
#  {'name': 'NUMBER OF PERSONS INJURED', 'id': 'NUMBER OF PERSONS INJURED'},
#  {'name': 'NUMBER OF PERSONS KILLED', 'id': 'NUMBER OF PERSONS KILLED'},
#  {'name': 'NUMBER OF PEDESTRIANS INJURED',
#   'id': 'NUMBER OF PEDESTRIANS INJURED'},
#  {'name': 'NUMBER OF PEDESTRIANS KILLED',
#   'id': 'NUMBER OF PEDESTRIANS KILLED'},
#  {'name': 'NUMBER OF CYCLIST INJURED', 'id': 'NUMBER OF CYCLIST INJURED'},
#  {'name': 'NUMBER OF CYCLIST KILLED', 'id': 'NUMBER OF CYCLIST KILLED'},
# ...

# %%
sns.histplot(df['YEAR'], kde=False, bins=len(df['YEAR'].unique()))
plt.title('Histogram of Incidents by Year')
plt.xlabel('Year')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['HOUR'], kde=False, bins=len(df['HOUR'].unique()))
plt.title('Histogram of Incidents by Hour')
plt.xlabel('Hour')
plt.ylabel('Frequency')
plt.show()

# %%
unique_years = sorted(df['YEAR'].dropna().unique())

# %%
unique_years
# Out:
# [np.int32(2012),
#  np.int32(2013),
#  np.int32(2014),
#  np.int32(2015),
#  np.int32(2016),
#  np.int32(2017),
#  np.int32(2018),
#  np.int32(2019),
#  np.int32(2020),
#  np.int32(2021),
#  np.int32(2022),
#  np.int32(2023),
#  np.int32(2024)]

# %%
years_int = [int(year) for year in unique_years]

# %%
years_int
# Out:
# [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
years_dict = {year: f"{year}" for year in years_int}

# %%
years_dict
# Out:
# {2012: '2012',
#  2013: '2013',
#  2014: '2014',
#  2015: '2015',
#  2016: '2016',
#  2017: '2017',
#  2018: '2018',
#  2019: '2019',
#  2020: '2020',
#  2021: '2021',
#  2022: '2022',
#  2023: '2023',
#  2024: '2024'}
