# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/harsnyi/Documents/NYC-Crash-Analysis/data/records.csv")
# Out:
# /var/folders/tw/j102_3791q18mc8161tjddq00000gn/T/ipykernel_12482/3879338386.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/harsnyi/Documents/NYC-Crash-Analysis/data/records.csv")

# %%
df.head()
# Out:
#    CRASH DATE           CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  2021-09-11  1900-01-01 02:39:00       NaN      NaN        NaN        NaN
# 1  2022-03-26  1900-01-01 11:45:00       NaN      NaN        NaN        NaN
# 2  2022-06-29  1900-01-01 06:55:00       NaN      NaN        NaN        NaN
# 3  2021-09-11  1900-01-01 09:35:00  BROOKLYN  11208.0  40.667202 -73.866500
# 4  2021-12-14  1900-01-01 08:13:00  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2127517 entries, 0 to 2127516
# Data columns (total 32 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   CRASH DATE                     object
#  1   CRASH TIME                     object
#  2   BOROUGH                        object
#  3   ZIP CODE                       object
#  4   LATITUDE                       float64
#  5   LONGITUDE                      float64
#  6   LOCATION                       object
#  7   ON STREET NAME                 object
#  8   CROSS STREET NAME              object
#  9   OFF STREET NAME                object
#  10  NUMBER OF PERSONS INJURED      float64
#  11  NUMBER OF PERSONS KILLED       float64
#  12  NUMBER OF PEDESTRIANS INJURED  int64
#  13  NUMBER OF PEDESTRIANS KILLED   int64
#  14  NUMBER OF CYCLIST INJURED      int64
#  15  NUMBER OF CYCLIST KILLED       int64
#  16  NUMBER OF MOTORIST INJURED     int64
# ...

# %%
df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'])
df['MONTH'] = df['CRASH DATE'].dt.month
df['DAY'] = df['CRASH DATE'].dt.day

# %%
df.head()
# Out:
#   CRASH DATE           CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0 2021-09-11  1900-01-01 02:39:00       NaN      NaN        NaN        NaN
# 1 2022-03-26  1900-01-01 11:45:00       NaN      NaN        NaN        NaN
# 2 2022-06-29  1900-01-01 06:55:00       NaN      NaN        NaN        NaN
# 3 2021-09-11  1900-01-01 09:35:00  BROOKLYN  11208.0  40.667202 -73.866500
# 4 2021-12-14  1900-01-01 08:13:00  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  \
# ...

# %%
df = df.drop(columns=['CRASH DATE', 'CRASH TIME'])

# %%
df.head()
# Out:
#     BOROUGH ZIP CODE   LATITUDE  LONGITUDE                 LOCATION  \
# 0       NaN      NaN        NaN        NaN                      NaN
# 1       NaN      NaN        NaN        NaN                      NaN
# 2       NaN      NaN        NaN        NaN                      NaN
# 3  BROOKLYN  11208.0  40.667202 -73.866500    (40.667202, -73.8665)
# 4  BROOKLYN  11233.0  40.683304 -73.917274  (40.683304, -73.917274)
#
#             ON STREET NAME CROSS STREET NAME          OFF STREET NAME  \
# 0    WHITESTONE EXPRESSWAY         20 AVENUE                      NaN
# 1  QUEENSBORO BRIDGE UPPER               NaN                      NaN
# 2       THROGS NECK BRIDGE               NaN                      NaN
# 3                      NaN               NaN  1211      LORING AVENUE
# 4          SARATOGA AVENUE    DECATUR STREET                      NaN
#
#    NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  ...  \
# 0                        2.0                       0.0  ...
# ...

# %%
df = df[df['YEAR'] != 2012]
df = df[df['YEAR'] != 2024]

# %%
df.to_csv("/Users/harsnyi/Documents/NYC-Crash-Analysis/data/NYC_crashes.csv", index=False)
